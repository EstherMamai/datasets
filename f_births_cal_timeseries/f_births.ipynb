# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#specify index column
#make sure date is parsed
df=pd.read_csv("D:\\datasets\\daily-total-female-births-in-cal.csv",index_col=[0],parse_dates=[0])

# %%
#convert dataframe to series
f_birth=df.squeeze()

# %%
f_birth.head()
# Out:
# Date
# 1959-01-01    35
# 1959-01-02    32
# 1959-01-03    30
# 1959-01-04    31
# 1959-01-05    44
# Name: Daily total female births in California, 1959, dtype: int64

# %%
type(f_birth)
# Out:
# pandas.core.series.Series

# %% [raw]
# #converting series to dataframe
# series_value=f_birth.values

# %%
series_value=f_birth.values

# %%
series_value
# Out:
# array([  35,   32,   30,   31,   44,   29,   45,   43,   38,   27,   38,
#          33,   55,   47,   45,   37,   50,   43,   41,   52,   34,   53,
#          39,   32,   37,   43,   39,   35,   44,   38,   24,   23,   31,
#          44,   38,   50,   38,   51,   31,   31,   51,   36,   45,   51,
#          34,   52,   47,   45,   46,   39,   48,   37,   35,   52,   42,
#          45,   39,   37,   30,   35,   28,   45,   34,   36,   50,   44,
#          39,   32,   39,   45,   43,   39,   31,   27,   30,   42,   46,
#          41,   36,   45,   46,   43,   38,   34,   35,   56,   36,   32,
#          50,   41,   39,   41,   47,   34,   36,   33,   35,   38,   38,
#          34,   53,   34,   34,   38,   35,   32,   42,   34,   46,   30,
#          46,   45,   54,   34,   37,   35,   40,   42,   58,   51,   32,
#          35,   38,   33,   39,   47,   38,   52,   30,   34,   40,   35,
#          42,   41,   42,   38,   24,   34,   43,   36,   55,   41,   45,
# ...

# %%
f_birth.size
# Out:
# 366

# %%
f_birth.tail()
# Out:
# Date
# 1959-12-28                                   52
# 1959-12-29                                   48
# 1959-12-30                                   55
# 1959-12-31                                   50
# Daily total female births in California    1959
# Name: Daily total female births in California, 1959, dtype: int64

# %%
f_birth.describe()
# Out:
# count     366.000000
# mean       47.218579
# std       100.472534
# min        23.000000
# 25%        37.000000
# 50%        42.000000
# 75%        46.000000
# max      1959.000000
# Name: Daily total female births in California, 1959, dtype: float64

# %%
f_birth=f_birth[0:365]

# %%
f_birth.describe()
# Out:
# count    365.000000
# mean      41.980822
# std        7.348257
# min       23.000000
# 25%       37.000000
# 50%       42.000000
# 75%       46.000000
# max       73.000000
# Name: Daily total female births in California, 1959, dtype: float64

# %%
f_birth.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#smoothing the series using moving averages
f_birth_mean=f_birth.rolling(window=10).mean()

# %%
f_birth.plot()
f_birth_mean.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#baseline model
